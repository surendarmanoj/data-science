# %% [markdown]
# <a href="https://colab.research.google.com/github/surendarmanoj/data-science/blob/main/Simple_Linear_regression_22_04_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_ds = iris[["petal_length","petal_width"]]
iris_ds
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
iris_ds.shape
# Out:
# (150, 2)

# %%
iris_ds.plot(kind="box")
plt.show()

# %%
iris_ds.corr()
# Out:
#               petal_length  petal_width
# petal_length      1.000000     0.962865
# petal_width       0.962865     1.000000

# %%
iris_new = iris[["sepal_length","sepal_width","petal_length","petal_width"]]
iris_new.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
X = iris["petal_length"]
y = iris['petal_width']

# %%
plt.scatter(X,y)
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=25)

# %%
X_train
# Out:
# 10     1.5
# 33     1.4
# 78     4.5
# 27     1.5
# 121    4.9
#       ...
# 118    6.9
# 61     4.2
# 143    5.9
# 62     4.0
# 132    5.6
# Name: petal_length, Length: 105, dtype: float64

# %%
X_train = np.array(X_train).reshape(-1,1)
X_train
# Out:
# array([[1.5],
#        [1.4],
#        [4.5],
#        [1.5],
#        [4.9],
#        [5.9],
#        [1.5],
#        [1.4],
#        [5.6],
#        [3.9],
#        [5.1],
#        [5.2],
#        [4.5],
#        [5.7],
#        [4.2],
#        [4.8],
#        [5.8],
#        [3.8],
#        [1.5],
#        [5. ],
#        [4.7],
#        [5.1],
#        [1.5],
#        [3.9],
#        [5. ],
#        [1.5],
#        [1.9],
#        [5.7],
#        [4.7],
#        [4.4],
#        [1.9],
#        [6.6],
#        [4.1],
#        [5.1],
#        [4.2],
#        [5.5],
#        [1.1],
#        [1.6],
#        [4. ],
#        [1.6],
#        [1.5],
#        [4.8],
#        [4.9],
#        [1.5],
#        [5.4],
#        [4. ],
#        [4.3],
#        [4.5],
#        [6.1],
#        [4.4],
#        [1.4],
#        [6. ],
#        [1.2],
#        [1.4],
#        [4.3],
#        [5.1],
#        [5.5],
#        [5. ],
#        [4.4],
#        [1.6],
#        [5.3],
#        [1.6],
# ...

# %%
X_test = np.array(X_test).reshape(-1,1)
X_test
# Out:
# array([[1.5],
#        [1.4],
#        [4.5],
#        [1.5],
#        [4.9],
#        [5.9],
#        [1.5],
#        [1.4],
#        [5.6],
#        [3.9],
#        [5.1],
#        [5.2],
#        [4.5],
#        [5.7],
#        [4.2],
#        [4.8],
#        [5.8],
#        [3.8],
#        [1.5],
#        [5. ],
#        [4.7],
#        [5.1],
#        [1.5],
#        [3.9],
#        [5. ],
#        [1.5],
#        [1.9],
#        [5.7],
#        [4.7],
#        [4.4],
#        [1.9],
#        [6.6],
#        [4.1],
#        [5.1],
#        [4.2],
#        [5.5],
#        [1.1],
#        [1.6],
#        [4. ],
#        [1.6],
#        [1.5],
#        [4.8],
#        [4.9],
#        [1.5],
#        [5.4],
#        [4. ],
#        [4.3],
#        [4.5],
#        [6.1],
#        [4.4],
#        [1.4],
#        [6. ],
#        [1.2],
#        [1.4],
#        [4.3],
#        [5.1],
#        [5.5],
#        [5. ],
#        [4.4],
#        [1.6],
#        [5.3],
#        [1.6],
# ...

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_

# %%
c
# Out:
# np.float64(-0.3991500417095035)

# %%
m = lr.coef_
m
# Out:
# array([0.42389392])

# %%
y_pred = (m * X_test) + c
y_pred.flatten()
# Out:
# array([0.23669084, 0.19430145, 1.5083726 , 0.23669084, 1.67793017,
#        2.10182409, 0.23669084, 0.19430145, 1.97465591, 1.25403625,
#        1.76270895, 1.80509834, 1.5083726 , 2.0170453 , 1.38120442,
#        1.63554078, 2.0594347 , 1.21164686, 0.23669084, 1.72031956,
#        1.59315138, 1.76270895, 0.23669084, 1.25403625, 1.72031956,
#        0.23669084, 0.40624841, 2.0170453 , 1.59315138, 1.46598321,
#        0.40624841, 2.39854983, 1.33881503, 1.76270895, 1.38120442,
#        1.93226652, 0.06713327, 0.27908023, 1.29642564, 0.27908023,
#        0.23669084, 1.63554078, 1.67793017, 0.23669084, 1.88987713,
#        1.29642564, 1.42359382, 1.5083726 , 2.18660287, 1.46598321,
#        0.19430145, 2.14421348, 0.10952266, 0.19430145, 1.42359382,
#        1.76270895, 1.93226652, 1.72031956, 1.46598321, 0.27908023,
#        1.84748774, 0.27908023, 0.02474388, 1.59315138, 0.9996999 ,
#        0.32146962, 0.15191205, 0.15191205, 1.93226652, 2.27138166,
# ...

# %%
Y_pred1 = lr.predict(X_test)
Y_pred1
# Out:
# array([0.23669084, 0.19430145, 1.5083726 , 0.23669084, 1.67793017,
#        2.10182409, 0.23669084, 0.19430145, 1.97465591, 1.25403625,
#        1.76270895, 1.80509834, 1.5083726 , 2.0170453 , 1.38120442,
#        1.63554078, 2.0594347 , 1.21164686, 0.23669084, 1.72031956,
#        1.59315138, 1.76270895, 0.23669084, 1.25403625, 1.72031956,
#        0.23669084, 0.40624841, 2.0170453 , 1.59315138, 1.46598321,
#        0.40624841, 2.39854983, 1.33881503, 1.76270895, 1.38120442,
#        1.93226652, 0.06713327, 0.27908023, 1.29642564, 0.27908023,
#        0.23669084, 1.63554078, 1.67793017, 0.23669084, 1.88987713,
#        1.29642564, 1.42359382, 1.5083726 , 2.18660287, 1.46598321,
#        0.19430145, 2.14421348, 0.10952266, 0.19430145, 1.42359382,
#        1.76270895, 1.93226652, 1.72031956, 1.46598321, 0.27908023,
#        1.84748774, 0.27908023, 0.02474388, 1.59315138, 0.9996999 ,
#        0.32146962, 0.15191205, 0.15191205, 1.93226652, 2.27138166,
# ...

# %%
plt.scatter(X_train,y_train)
plt.scatter(X_train,y_pred)
plt.plot(X_train,y_pred, color="red")

plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %%
y_prred_new = lr.predict([[3.5]])
y_prred_new
# Out:
# array([1.08447868])
